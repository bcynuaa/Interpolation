# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 11)
y = x**5/120 - x**4/24 + x**3/6 - x**2/2 + x - 1

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([-1.        , -0.60651042, -0.36666667, -0.21015625, -0.06666667,
#         0.16536458,  0.65      ,  1.64505208,  3.53333333,  6.85390625,
#        12.33333333])

# %%
data = np.loadtxt("../../bin/test/CubicSplineTest/CubicSplineTest.dat")

# %%
plt.figure(figsize=(8, 4))
plt.plot(data[:, 0], data[:, 1], color="b")
plt.plot(x, y, "o", color="r", zorder=10)
plt.show()

# %%
y1 = 5*x**4/120 - 4*x**3/24 + 3*x**2/6 - 2*x/2 + 1
plt.figure(figsize=(8, 4))
plt.plot(data[:, 0], data[:, 2], color="b")
plt.plot(x, y1, "o", color="r", zorder=10)
plt.show()

# %%
y2 = 20*x**3/120 - 12*x**2/24 + 6*x/6 - 2/2
plt.figure(figsize=(8, 4))
plt.plot(data[:, 0], data[:, 3], color="b")
plt.plot(x, y2, "o", color="r", zorder=10)
plt.show()
